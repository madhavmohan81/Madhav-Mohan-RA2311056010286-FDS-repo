# %%
import numpy as np
from numpy import random
x = random.randint(100)
print(x)
# Out:
# 52

# %%
import numpy as np
from numpy import random
x = random.rand(4)
print(x)
# Out:
# [0.54163797 0.8369005  0.38547102 0.36648201]

# %%
import numpy as np
from numpy import random
x = random.choice([1,5,7,6], p=[0.1,0.5,0.4,0.0],size =(100))
print(x)
# Out:
# [5 7 5 5 5 5 7 5 7 5 7 7 1 7 5 7 1 5 5 5 7 7 7 5 7 7 7 5 5 5 7 5 7 5 1 1 7
#  5 7 5 7 7 5 5 7 5 7 5 5 7 1 7 7 5 7 1 5 5 5 7 5 7 5 7 7 7 5 1 5 5 5 5 1 5
#  7 1 5 7 5 5 7 5 7 5 5 7 5 1 1 1 5 1 5 5 7 5 7 5 5 5]

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot(random.normal(size=1000))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate 1000 random numbers from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)

# Create a histogram plot using Seaborn
sns.displot(data, kde=False, bins=30)

# Set plot title and axis labels
plt.title("Histogram of Random Normal Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %%
import numpy as np
from numpy import random
x = random.binomial(n=10,p=0.5,size=10)
print(x)
# Out:
# [9 5 6 6 5 4 4 6 7 8]

# %%
import numpy as np
from numpy import random
x = random.exponential(scale=2,size=(2,3))
print(x)
# Out:
# [[1.23037716 0.56348413 1.06678243]
#  [0.98880486 1.40955218 1.02130003]]
